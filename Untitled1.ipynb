# %%
### 패키지 설치 
import pandas as pd #Analysis 
import matplotlib.pyplot as plt #Visulization
plt.rc("font", family="Malgun Gothic")
import seaborn as sns #Visulization
import numpy as np #Analysis

# %%
train=pd.read_csv('data/funda.csv',low_memory=False)

# %%
#대상이 되는 카드사로 새로운 테이블 생성
train_company = train[train['card_company'] == 'a']
train_company
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 3               0        3            a      2016-06-01           20:22
# 7               0        7            a      2016-06-02           17:18
# 9               0        9            a      2016-06-02           19:56
# 14              0       14            a      2016-06-04           11:15
# 17              0       17            a      2016-06-04           14:32
# ...           ...      ...          ...             ...             ...
# 6556598      2136  4661654            a      2019-02-28           01:04
# 6556599      2136  4663850            a      2019-02-28           02:35
# 6556600      2136  4663107            a      2019-02-28           21:20
# 6556603      2136  4663852            a      2019-02-28           22:35
# 6556610      2136  4663489            a      2019-02-28           23:24
#
#          installment_term  region type_of_business       amount  year  month  \
# ...

# %%
train_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1828556 entries, 3 to 6556610
# Data columns (total 19 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   store_id          int64
#  1   card_id           int64
#  2   card_company      object
#  3   transacted_date   object
#  4   transacted_time   object
#  5   installment_term  int64
#  6   region            object
#  7   type_of_business  object
#  8   amount            float64
#  9   year              int64
#  10  month             int64
#  11  dayofweek         int64
#  12  year-month        object
#  13  season            object
#  14  quarter           int64
#  15  hour              int64
#  16  sido              object
#  17  city              object
#  18  holidays          int64
# dtypes: float64(1), int64(9), object(9)
# memory usage: 279.0+ MB

# %%
sns.countplot(train_company['transacted_date'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='transacted_date', ylabel='count'>

# %%
train_b = train[train['card_company'] == 'b']

# %%
sns.countplot(train_b['transacted_date'])
# Out:
# <AxesSubplot:xlabel='transacted_date', ylabel='count'>
